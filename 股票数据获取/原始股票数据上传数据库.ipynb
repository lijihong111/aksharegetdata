# %%
#参数设置
import pandas as pd
import numpy as np
import datetime
import akshare as ak
from datetime import timedelta
from sqlalchemy import create_engine


startdate=datetime.datetime.now().strftime("%Y-%m-%d")
startdate
enddate=startdate
sdate=datetime.datetime.now().strftime("%Y%m%d")
sdate
edate=sdate
adjustway='qfq'
StockListdf=pd.read_csv('./data/stockList_del_cyb_qian.csv')
StockList=StockListdf['code'].tolist()
StockListdf['code']=StockListdf['code'].astype(str)
StockListdf['code']=StockListdf['code'].map(lambda x:x.zfill(6))
StockListdf.rename(columns={'code':'代码'},inplace=True)
lastmonthday=datetime.datetime.now()+datetime.timedelta(days=-30)
lastmonthday=lastmonthday.strftime("%Y%m%d")
# Out:
# /Users/mac/anaconda3/lib/python3.7/site-packages/pandas/compat/_optional.py:138: UserWarning: Pandas requires version '2.7.0' or newer of 'numexpr' (version '2.6.9' currently installed).
#   warnings.warn(msg, UserWarning)

# %%
#连接引擎
conn = create_engine('mysql+pymysql://root:admin@localhost:3306/FirstDataBase?charset=utf8')


try:
    stock_zh_a_st_em_df = ak.stock_zh_a_st_em()
except:
    print('stock_zh_a_st_em_df出错了！！！！！')
else:
    stock_zh_a_st_em_df=stock_zh_a_st_em_df.add_prefix('stock_zh_a_st_em_')
    stock_zh_a_st_em_df['date']=startdate
try:
    pd.io.sql.to_sql(stock_zh_a_st_em_df,'stock_zh_a_st_em',con=conn,if_exists='append',index=False)
except:
    print('stock_zh_a_st_em_df数据库写入失败')


try:
    stock_ipo_benefit_ths_df = ak.stock_ipo_benefit_ths()
except:
    print('stock_ipo_benefit_ths_df出错了！！！！！')
else:
    stock_ipo_benefit_ths_df=stock_ipo_benefit_ths_df.add_prefix('stock_ipo_benefit_ths_')
    stock_ipo_benefit_ths_df['date']=startdate
try:
    pd.io.sql.to_sql(stock_ipo_benefit_ths_df,'stock_ipo_benefit_ths',con=conn,if_exists='append',index=False)
except:
    print('stock_ipo_benefit_ths_df数据库写入失败')
    

try:
    stock_zh_index_spot_df = ak.stock_zh_index_spot()
except:
    print('stock_zh_index_spot_df出错了！！！！！')
else:
    stock_zh_index_spot_df=stock_zh_index_spot_df.add_prefix('stock_zh_index_spot_')
    stock_zh_index_spot_df['date']=startdate
try:
    pd.io.sql.to_sql(stock_zh_index_spot_df,'stock_zh_index_spot',con=conn,if_exists='append',index=False)
except:
    print('stock_zh_index_spot_df数据库写入失败')


try:
    stock_zh_ah_spot_df = ak.stock_zh_ah_spot()
except:
    print('stock_zh_ah_spot_df出错了！！！！！')
else:
    stock_zh_ah_spot_df=stock_zh_ah_spot_df.add_prefix('stock_zh_ah_spot_')
    stock_zh_ah_spot_df['date']=startdate
try:
    pd.io.sql.to_sql(stock_zh_ah_spot_df,'stock_zh_ah_spot',con=conn,if_exists='append',index=False)
except:
    print('stock_zh_ah_spot_df数据库写入失败')
    

try:
    stock_jgdy_tj_em_df = ak.stock_jgdy_tj_em()
except:
    print('stock_jgdy_tj_em_df出错了！！！！！')
else:
    stock_jgdy_tj_em_df=stock_jgdy_tj_em_df.add_prefix('stock_jgdy_tj_em_')
    stock_jgdy_tj_em_df['date']=startdate
try:
    pd.io.sql.to_sql(stock_jgdy_tj_em_df,'stock_jgdy_tj_em',con=conn,if_exists='append',index=False)
except:
    print('stock_jgdy_tj_em_df数据库写入失败')
    

try:
    stock_gpzy_pledge_ratio_em_df = ak.stock_gpzy_pledge_ratio_em()
except:
    print('stock_gpzy_pledge_ratio_em_df出错了！！！！！')
else:
    stock_gpzy_pledge_ratio_em_df=stock_gpzy_pledge_ratio_em_df.add_prefix('stock_gpzy_pledge_ratio_em_')
    stock_gpzy_pledge_ratio_em_df['date']=startdate
try:
    pd.io.sql.to_sql(stock_gpzy_pledge_ratio_em_df,'stock_gpzy_pledge_ratio_em',con=conn,if_exists='append',index=False)
except:
    print('stock_gpzy_pledge_ratio_em_df数据库写入失败')
    

try:
    stock_gpzy_industry_data_em_df = ak.stock_gpzy_industry_data_em()
except:
    print('stock_gpzy_industry_data_em_df出错了！！！！！')
else:
    stock_gpzy_industry_data_em_df=stock_gpzy_industry_data_em_df.add_prefix('stock_gpzy_industry_data_em_')
    stock_gpzy_industry_data_em_df['date']=startdate
try:
    pd.io.sql.to_sql(stock_gpzy_industry_data_em_df,'stock_gpzy_industry_data_em',con=conn,if_exists='append',index=False)
except:
    print('stock_gpzy_industry_data_em_df数据库写入失败')
    
    
try:
    stock_comment_detail_zlkp_jgcyd_em_df = ak.stock_comment_detail_zlkp_jgcyd_em()
except:
    print('stock_comment_detail_zlkp_jgcyd_em_df出错了！！！！！')
else:
    stock_comment_detail_zlkp_jgcyd_em_df=stock_comment_detail_zlkp_jgcyd_em_df.add_prefix('stock_comment_detail_zlkp_jgcyd_em_')
    stock_comment_detail_zlkp_jgcyd_em_df['date']=startdate
try:
    pd.io.sql.to_sql(stock_comment_detail_zlkp_jgcyd_em_df,'stock_comment_detail_zlkp_jgcyd_em',con=conn,if_exists='append',index=False)
except:
    print('stock_comment_detail_zlkp_jgcyd_em_df数据库写入失败')

try:
    stock_comment_em_df = ak.stock_comment_em()
except:
    print('stock_comment_em_df出错了！！！！！')
else:
    stock_comment_em_df=stock_comment_em_df.add_prefix('stock_comment_em_')
    stock_comment_em_df['date']=startdate
try:
    pd.io.sql.to_sql(stock_comment_em_df,'stock_comment_em',con=conn,if_exists='append',index=False)
except:
    print('stock_comment_em_df数据库写入失败')

try:
    stock_hk_ggt_components_em_df = ak.stock_hk_ggt_components_em()
except:
    print('stock_hk_ggt_components_em_df出错了！！！！！')
else:
    stock_hk_ggt_components_em_df=stock_hk_ggt_components_em_df.add_prefix('stock_hk_ggt_components_em_')
    stock_hk_ggt_components_em_df['date']=startdate
try:
    pd.io.sql.to_sql(stock_hk_ggt_components_em_df,'stock_hk_ggt_components_em',con=conn,if_exists='append',index=False)
except:
    print('stock_hk_ggt_components_em_df数据库写入失败')

try:
    stock_em_hsgt_hold_stock_df_today = ak.stock_hsgt_hold_stock_em(market="北向", indicator="今日排行")
except:
    print('stock_em_hsgt_hold_stock_df_today出错了！！！！！')
else:
    stock_em_hsgt_hold_stock_df_today=stock_em_hsgt_hold_stock_df_today.add_prefix('stock_hsgt_hold_stock_em_today_')
    stock_em_hsgt_hold_stock_df_today['date']=startdate
try:
    pd.io.sql.to_sql(stock_em_hsgt_hold_stock_df_today,'stock_hsgt_hold_stock_em_today',con=conn,if_exists='append',index=False)
except:
    print('stock_em_hsgt_hold_stock_df_today数据库写入失败')

try:
    stock_em_hsgt_hold_stock_df_3day = ak.stock_hsgt_hold_stock_em(market="北向", indicator="3日排行")
except:
    print('stock_em_hsgt_hold_stock_df_3day出错了！！！！！')
else:
    stock_em_hsgt_hold_stock_df_3day=stock_em_hsgt_hold_stock_df_3day.add_prefix('stock_hsgt_hold_stock_em_3day_')
    stock_em_hsgt_hold_stock_df_3day['date']=startdate
try:
    pd.io.sql.to_sql(stock_em_hsgt_hold_stock_df_3day,'stock_hsgt_hold_stock_em_3day',con=conn,if_exists='append',index=False)
except:
    print('stock_em_hsgt_hold_stock_df_3day数据库写入失败')

try:
    stock_em_hsgt_hold_stock_df_5day = ak.stock_hsgt_hold_stock_em(market="北向", indicator="5日排行")
except:
    print('stock_em_hsgt_hold_stock_df_5day出错了！！！！！')
else:
    stock_em_hsgt_hold_stock_df_5day=stock_em_hsgt_hold_stock_df_5day.add_prefix('stock_hsgt_hold_stock_em_5day_')
    stock_em_hsgt_hold_stock_df_5day['date']=startdate
try:
    pd.io.sql.to_sql(stock_em_hsgt_hold_stock_df_5day,'stock_hsgt_hold_stock_em_5day',con=conn,if_exists='append',index=False)
except:
    print('stock_em_hsgt_hold_stock_df_5day数据库写入失败')

try:
    stock_em_hsgt_hold_stock_df_10day = ak.stock_hsgt_hold_stock_em(market="北向", indicator="10日排行")
except:
    print('stock_em_hsgt_hold_stock_df_10day出错了！！！！！')
else:
    stock_em_hsgt_hold_stock_df_10day=stock_em_hsgt_hold_stock_df_10day.add_prefix('stock_hsgt_hold_stock_em_10day_')
    stock_em_hsgt_hold_stock_df_10day['date']=startdate
try:
    pd.io.sql.to_sql(stock_em_hsgt_hold_stock_df_10day,'stock_hsgt_hold_stock_em_10day',con=conn,if_exists='append',index=False)
except:
    print('stock_em_hsgt_hold_stock_df_10day数据库写入失败')

try:
    stock_em_hsgt_hold_stock_df_month = ak.stock_hsgt_hold_stock_em(market="北向", indicator="月排行")
except:
    print('stock_em_hsgt_hold_stock_df_month出错了！！！！！')
else:
    stock_em_hsgt_hold_stock_df_month=stock_em_hsgt_hold_stock_df_month.add_prefix('stock_hsgt_hold_stock_em_month_')
    stock_em_hsgt_hold_stock_df_month['date']=startdate
try:
    pd.io.sql.to_sql(stock_em_hsgt_hold_stock_df_month,'stock_hsgt_hold_stock_em_month',con=conn,if_exists='append',index=False)
except:
    print('stock_em_hsgt_hold_stock_df_month数据库写入失败')

try:
    stock_tfp_em_df = ak.stock_tfp_em(date=sdate)
except:
    print('stock_tfp_em_df出错了！！！！！')
else:
    stock_tfp_em_df=stock_tfp_em_df.add_prefix('stock_tfp_em_')
    stock_tfp_em_df['date']=startdate
try:
    pd.io.sql.to_sql(stock_tfp_em_df,'stock_tfp_em',con=conn,if_exists='append',index=False)
except:
    print('stock_tfp_em_df数据库写入失败')
    

try:
    stock_fund_flow_individual_df_today = ak.stock_fund_flow_individual(symbol="即时")
except:
    print('stock_fund_flow_individual_df_today出错了！！！！！')
else:
    stock_fund_flow_individual_df_today=stock_fund_flow_individual_df_today.add_prefix('stock_fund_flow_individual_today_')
    stock_fund_flow_individual_df_today['date']=startdate
try:
    pd.io.sql.to_sql(stock_fund_flow_individual_df_today,'stock_fund_flow_individual_today',con=conn,if_exists='append',index=False)
except:
    print('stock_fund_flow_individual_df_today数据库写入失败')
    
def tra(x):
    x=str(x)
    if(x[-1]=='万'):
        return float(x[:-1])*10000
    if(x[-1]=='亿'):
        return float(x[:-1])*100000000
    else:
        return x

def delper(x):
    x=str(x)
    if(x[-1]=='%'):
        return float(x[:-1])
    else:
        return float(x)

try:
    stock_fund_flow_individual_df_today = ak.stock_fund_flow_individual(symbol="即时")
    stock_fund_flow_individual_df_today['股票代码']=stock_fund_flow_individual_df_today['股票代码'].astype(str)
    stock_fund_flow_individual_df_today['股票代码']=stock_fund_flow_individual_df_today['股票代码'].map(lambda x:x.zfill(6))
    stock_fund_flow_individual_df_today['流入资金']=stock_fund_flow_individual_df_today['流入资金'].apply(tra)
    stock_fund_flow_individual_df_today['流出资金']=stock_fund_flow_individual_df_today['流出资金'].apply(tra)
    stock_fund_flow_individual_df_today['净额']=stock_fund_flow_individual_df_today['净额'].apply(tra)
    stock_fund_flow_individual_df_today['成交额']=stock_fund_flow_individual_df_today['成交额'].apply(tra)
except:
    print('stock_fund_flow_individual_df_today出错了！！！！！')
else:
    stock_fund_flow_individual_df_today=stock_fund_flow_individual_df_today.add_prefix('stock_fund_flow_individual_today_')
    stock_fund_flow_individual_df_today['date']=startdate
try:
    pd.io.sql.to_sql(stock_fund_flow_individual_df_today,'stock_fund_flow_individual_today',con=conn,if_exists='append',index=False)
except:
    print('stock_fund_flow_individual_df_today数据库写入失败')

    
try:
    stock_fund_flow_individual_df_3day = ak.stock_fund_flow_individual(symbol="3日排行")
    stock_fund_flow_individual_df_3day['股票代码']=stock_fund_flow_individual_df_3day['股票代码'].astype(str)
    stock_fund_flow_individual_df_3day['股票代码']=stock_fund_flow_individual_df_3day['股票代码'].map(lambda x:x.zfill(6))
    stock_fund_flow_individual_df_3day['资金流入净额']=stock_fund_flow_individual_df_3day['资金流入净额'].apply(tra)
except:
    print('stock_fund_flow_individual_df_3day出错了！！！！！')
else:
    stock_fund_flow_individual_df_3day=stock_fund_flow_individual_df_3day.add_prefix('stock_fund_flow_individual_3day_')
    stock_fund_flow_individual_df_3day['date']=startdate
try:
    pd.io.sql.to_sql(stock_fund_flow_individual_df_3day,'stock_fund_flow_individual_3day',con=conn,if_exists='append',index=False)
except:
    print('stock_fund_flow_individual_df_3day数据库写入失败')
    
    
try:
    stock_fund_flow_individual_df_5day = ak.stock_fund_flow_individual(symbol="5日排行")
    stock_fund_flow_individual_df_5day['股票代码']=stock_fund_flow_individual_df_5day['股票代码'].astype(str)
    stock_fund_flow_individual_df_5day['股票代码']=stock_fund_flow_individual_df_5day['股票代码'].map(lambda x:x.zfill(6))
    stock_fund_flow_individual_df_5day['资金流入净额']=stock_fund_flow_individual_df_5day['资金流入净额'].apply(tra)
except:
    print('stock_fund_flow_individual_df_5day出错了！！！！！')
else:
    stock_fund_flow_individual_df_5day=stock_fund_flow_individual_df_5day.add_prefix('stock_fund_flow_individual_5day_')
    stock_fund_flow_individual_df_5day['date']=startdate
try:
    pd.io.sql.to_sql(stock_fund_flow_individual_df_5day,'stock_fund_flow_individual_5day',con=conn,if_exists='append',index=False)
except:
    print('stock_fund_flow_individual_df_5day数据库写入失败')
    
    
try:
    stock_fund_flow_individual_df_10day = ak.stock_fund_flow_individual(symbol="10日排行")
    stock_fund_flow_individual_df_10day['股票代码']=stock_fund_flow_individual_df_10day['股票代码'].astype(str)
    stock_fund_flow_individual_df_10day['股票代码']=stock_fund_flow_individual_df_10day['股票代码'].map(lambda x:x.zfill(6))
    stock_fund_flow_individual_df_10day['资金流入净额']=stock_fund_flow_individual_df_10day['资金流入净额'].apply(tra)
except:
    print('stock_fund_flow_individual_df_10day出错了！！！！！')
else:
    stock_fund_flow_individual_df_10day=stock_fund_flow_individual_df_10day.add_prefix('stock_fund_flow_individual_10day_')
    stock_fund_flow_individual_df_10day['date']=startdate
try:
    pd.io.sql.to_sql(stock_fund_flow_individual_df_10day,'stock_fund_flow_individual_10day',con=conn,if_exists='append',index=False)
except:
    print('stock_fund_flow_individual_df_10day数据库写入失败')
    
    
try:
    stock_fund_flow_individual_df_20day = ak.stock_fund_flow_individual(symbol="20日排行")
    stock_fund_flow_individual_df_20day['股票代码']=stock_fund_flow_individual_df_20day['股票代码'].astype(str)
    stock_fund_flow_individual_df_20day['股票代码']=stock_fund_flow_individual_df_20day['股票代码'].map(lambda x:x.zfill(6))
    stock_fund_flow_individual_df_20day['资金流入净额']=stock_fund_flow_individual_df_20day['资金流入净额'].apply(tra)
except:
    print('stock_fund_flow_individual_df_20day出错了！！！！！')
else:
    stock_fund_flow_individual_df_20day=stock_fund_flow_individual_df_20day.add_prefix('stock_fund_flow_individual_20day_')
    stock_fund_flow_individual_df_20day['date']=startdate
try:
    pd.io.sql.to_sql(stock_fund_flow_individual_df_20day,'stock_fund_flow_individual_20day',con=conn,if_exists='append',index=False)
except:
    print('stock_fund_flow_individual_df_20day数据库写入失败')
    

try:
    stock_individual_fund_flow_rank_df_today = ak.stock_individual_fund_flow_rank(indicator="今日")
except:
    print('stock_individual_fund_flow_rank_df_today出错了！！！！！')
else:
    stock_individual_fund_flow_rank_df_today = stock_individual_fund_flow_rank_df_today.add_prefix('stock_individual_fund_flow_rank_df_today_')
    stock_individual_fund_flow_rank_df_today['date']=startdate
try:
    pd.io.sql.to_sql(stock_individual_fund_flow_rank_df_today,'stock_individual_fund_flow_rank_df_today',con=conn,if_exists='append',index=False)
except:
    print('stock_individual_fund_flow_rank_df_today数据库写入失败')
    

try:
    stock_individual_fund_flow_rank_df_3day = ak.stock_individual_fund_flow_rank(indicator="3日")
except:
    print('stock_individual_fund_flow_rank_df_3day出错了！！！！！')
else:
    stock_individual_fund_flow_rank_df_3day = stock_individual_fund_flow_rank_df_3day.add_prefix('stock_individual_fund_flow_rank_df_3day_')
    stock_individual_fund_flow_rank_df_3day['date']=startdate
try:
    pd.io.sql.to_sql(stock_individual_fund_flow_rank_df_3day,'stock_individual_fund_flow_rank_df_3day',con=conn,if_exists='append',index=False)
except:
    print('stock_individual_fund_flow_rank_df_3day数据库写入失败')
    
    
try:
    stock_individual_fund_flow_rank_df_5day = ak.stock_individual_fund_flow_rank(indicator="5日")
except:
    print('stock_individual_fund_flow_rank_df_5day出错了！！！！！')
else:
    stock_individual_fund_flow_rank_df_5day = stock_individual_fund_flow_rank_df_5day.add_prefix('stock_individual_fund_flow_rank_df_5day_')
    stock_individual_fund_flow_rank_df_5day['date']=startdate
try:
    pd.io.sql.to_sql(stock_individual_fund_flow_rank_df_5day,'stock_individual_fund_flow_rank_df_5day',con=conn,if_exists='append',index=False)
except:
    print('stock_individual_fund_flow_rank_df_5day数据库写入失败')
    

try:
    stock_individual_fund_flow_rank_df_10day = ak.stock_individual_fund_flow_rank(indicator="10日")
except:
    print('stock_individual_fund_flow_rank_df_10day出错了！！！！！')
else:
    stock_individual_fund_flow_rank_df_10day = stock_individual_fund_flow_rank_df_10day.add_prefix('stock_individual_fund_flow_rank_df_10day_')
    stock_individual_fund_flow_rank_df_10day['date']=startdate
try:
    pd.io.sql.to_sql(stock_individual_fund_flow_rank_df_10day,'stock_individual_fund_flow_rank_df_10day',con=conn,if_exists='append',index=False)
except:
    print('stock_individual_fund_flow_rank_df_10day数据库写入失败')

# %%
#关闭
conn.dispose()

# %%
#需要时间测试
stock_comment_detail_zlkp_jgcyd_em_df_all=pd.DataFrame()
for i in StockList:
    i=str(i).zfill(6)
    try:
        stock_comment_detail_zlkp_jgcyd_em_df = ak.stock_comment_detail_zlkp_jgcyd_em(symbol=i)
        stock_comment_detail_zlkp_jgcyd_em_df['代码']=i
    except:
        #print('i stock_comment_detail_zlkp_jgcyd_em_df出错了！！！！！')
        continue
    else:
        stock_comment_detail_zlkp_jgcyd_em_df_all=stock_comment_detail_zlkp_jgcyd_em_df_all.append(stock_comment_detail_zlkp_jgcyd_em_df,ignore_index=True)
try:
    stock_comment_detail_zlkp_jgcyd_em_df_all.add_prefix('stock_comment_detail_zlkp_jgcyd_em_')
    pd.io.sql.to_sql(stock_comment_detail_zlkp_jgcyd_em_df_all,'stock_comment_detail_zlkp_jgcyd_em',con=conn,if_exists='replace',index=False)
except:
    print('stock_comment_detail_zlkp_jgcyd_em_df数据库写入失败')
    
stock_comment_detail_zhpj_lspf_em_df_all=pd.DataFrame()
for i in StockList:
    i=str(i).zfill(6)
    try:
        stock_comment_detail_zhpj_lspf_em_df = ak.stock_comment_detail_zhpj_lspf_em(symbol=i)
        stock_comment_detail_zhpj_lspf_em_df['代码']=i
    except:
        #print('i stock_comment_detail_zhpj_lspf_em_df出错了！！！！！')
        continue
    else:
        stock_comment_detail_zhpj_lspf_em_df_all=stock_comment_detail_zhpj_lspf_em_df_all.append(stock_comment_detail_zhpj_lspf_em_df,ignore_index=True)
try:
    stock_comment_detail_zhpj_lspf_em_df_all.add_prefix('stock_comment_detail_zhpj_lspf_em_')
    pd.io.sql.to_sql(stock_comment_detail_zhpj_lspf_em_df_all,'stock_comment_detail_zhpj_lspf_em',con=conn,if_exists='replace',index=False)
except:
    print('stock_comment_detail_zhpj_lspf_em_df数据库写入失败')
    
stock_comment_detail_scrd_focus_em_df_all=pd.DataFrame()
for i in StockList:
    i=str(i).zfill(6)
    try:
        stock_comment_detail_scrd_focus_em_df = ak.stock_comment_detail_scrd_focus_em(symbol=i)
        stock_comment_detail_scrd_focus_em_df['代码']=i
    except:
        #print('i stock_comment_detail_scrd_focus_em_df出错了！！！！！')
        continue
    else:
        stock_comment_detail_scrd_focus_em_df_all=stock_comment_detail_scrd_focus_em_df_all.append(stock_comment_detail_scrd_focus_em_df,ignore_index=True)
try:
    stock_comment_detail_scrd_focus_em_df_all.add_prefix('stock_comment_detail_scrd_focus_em_')
    pd.io.sql.to_sql(stock_comment_detail_scrd_focus_em_df_all,'stock_comment_detail_scrd_focus_em',con=conn,if_exists='replace',index=False)
except:
    print('stock_comment_detail_scrd_focus_em_df数据库写入失败')
    
stock_comment_detail_scrd_desire_daily_em_df_all=pd.DataFrame()
for i in StockList:
    i=str(i).zfill(6)
    try:
        stock_comment_detail_scrd_desire_daily_em_df = ak.stock_comment_detail_scrd_desire_daily_em(symbol=i)
        stock_comment_detail_scrd_desire_daily_em_df['代码']=i
    except:
        #print('i stock_comment_detail_scrd_desire_daily_em_df出错了！！！！！')
        continue
    else:
        stock_comment_detail_scrd_desire_daily_em_df_all=stock_comment_detail_scrd_desire_daily_em_df_all.append(stock_comment_detail_scrd_desire_daily_em_df,ignore_index=True)
try:
    stock_comment_detail_scrd_desire_daily_em_df_all.add_prefix('stock_comment_detail_scrd_desire_daily_em_')
    pd.io.sql.to_sql(stock_comment_detail_scrd_desire_daily_em_df_all,'stock_comment_detail_scrd_desire_daily_em',con=conn,if_exists='replace',index=False)
except:
    print('stock_comment_detail_scrd_desire_daily_em_df数据库写入失败')
    
stock_comment_detail_scrd_cost_em_df_all=pd.DataFrame()
for i in StockList:
    i=str(i).zfill(6)
    try:
        stock_comment_detail_scrd_cost_em_df = ak.stock_comment_detail_scrd_cost_em(symbol=i)
        stock_comment_detail_scrd_cost_em_df['代码']=i
    except:
        #print('i stock_comment_detail_scrd_cost_em_df出错了！！！！！')
        continue
    else:
        stock_comment_detail_scrd_cost_em_df_all=stock_comment_detail_scrd_cost_em_df_all.append(stock_comment_detail_scrd_cost_em_df,ignore_index=True)
try:
    stock_comment_detail_scrd_cost_em_df_all.add_prefix('stock_comment_detail_scrd_cost_em_')
    pd.io.sql.to_sql(stock_comment_detail_scrd_cost_em_df_all,'stock_comment_detail_scrd_cost_em',con=conn,if_exists='replace',index=False)
except:
    print('stock_comment_detail_scrd_cost_em_df数据库写入失败')
    
    
    
    
    
    
    
    
    
    
    
#暂时不用
#板块排行
stock_hsgt_board_rank_em
#沪深港通持股-个股 
stock_hsgt_individual_em
