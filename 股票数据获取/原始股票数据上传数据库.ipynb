# %%
#参数设置
import pandas as pd
import numpy as np
import datetime
import akshare as ak
from datetime import timedelta
from sqlalchemy import create_engine


startdate=datetime.datetime.now().strftime("%Y-%m-%d")
startdate
enddate=startdate
sdate=datetime.datetime.now().strftime("%Y%m%d")
sdate
edate=sdate
adjustway='qfq'
StockListdf=pd.read_csv('./data/stockList_del_cyb_qian.csv')
StockList=StockListdf['code'].tolist()
StockListdf['code']=StockListdf['code'].astype(str)
StockListdf['code']=StockListdf['code'].map(lambda x:x.zfill(6))
StockListdf.rename(columns={'code':'代码'},inplace=True)
lastmonthday=datetime.datetime.now()+datetime.timedelta(days=-30)
lastmonthday=lastmonthday.strftime("%Y%m%d")
# Out:
# /Users/mac/anaconda3/lib/python3.7/site-packages/pandas/compat/_optional.py:138: UserWarning: Pandas requires version '2.7.0' or newer of 'numexpr' (version '2.6.9' currently installed).
#   warnings.warn(msg, UserWarning)

# %%
#连接引擎
conn = create_engine('mysql+pymysql://root:admin@localhost:3306/FirstDataBase?charset=utf8')


try:
    stock_zh_a_spot_em_df = ak.stock_zh_a_spot_em()
    stock_zh_a_spot_em_df.rename(columns={'证券代码':'代码'},inplace=True)
except:
    print('stock_zh_a_spot_em_df出错了！！！！！')
else:
    stock_zh_a_spot_em_df=stock_zh_a_spot_em_df.add_prefix('stock_zh_a_spot_em_')
    stock_zh_a_spot_em_df['date']=startdate
try:
    pd.io.sql.to_sql(stock_zh_a_spot_em_df,'stock_zh_a_spot_em',con=conn,if_exists='append',index=False)
except:
    print('stock_zh_a_spot_em_df数据库写入失败')

try:
    stock_zh_a_st_em_df = ak.stock_zh_a_st_em()
except:
    print('stock_zh_a_st_em_df出错了！！！！！')
else:
    stock_zh_a_st_em_df=stock_zh_a_st_em_df.add_prefix('stock_zh_a_st_em_')
    stock_zh_a_st_em_df['date']=startdate
try:
    pd.io.sql.to_sql(stock_zh_a_st_em_df,'stock_zh_a_st_em',con=conn,if_exists='append',index=False)
except:
    print('stock_zh_a_st_em_df数据库写入失败')


try:
    stock_ipo_benefit_ths_df = ak.stock_ipo_benefit_ths()
except:
    print('stock_ipo_benefit_ths_df出错了！！！！！')
else:
    stock_ipo_benefit_ths_df=stock_ipo_benefit_ths_df.add_prefix('stock_ipo_benefit_ths_')
    stock_ipo_benefit_ths_df['date']=startdate
try:
    pd.io.sql.to_sql(stock_ipo_benefit_ths_df,'stock_ipo_benefit_ths',con=conn,if_exists='append',index=False)
except:
    print('stock_ipo_benefit_ths_df数据库写入失败')


try:
    stock_zh_ah_spot_df = ak.stock_zh_ah_spot()
except:
    print('stock_zh_ah_spot_df出错了！！！！！')
else:
    stock_zh_ah_spot_df=stock_zh_ah_spot_df.add_prefix('stock_zh_ah_spot_')
    stock_zh_ah_spot_df['date']=startdate
try:
    pd.io.sql.to_sql(stock_zh_ah_spot_df,'stock_zh_ah_spot',con=conn,if_exists='append',index=False)
except:
    print('stock_zh_ah_spot_df数据库写入失败')
    

try:
    stock_jgdy_tj_em_df = ak.stock_jgdy_tj_em()
except:
    print('stock_jgdy_tj_em_df出错了！！！！！')
else:
    stock_jgdy_tj_em_df=stock_jgdy_tj_em_df.add_prefix('stock_jgdy_tj_em_')
    stock_jgdy_tj_em_df['date']=startdate
try:
    pd.io.sql.to_sql(stock_jgdy_tj_em_df,'stock_jgdy_tj_em',con=conn,if_exists='append',index=False)
except:
    print('stock_jgdy_tj_em_df数据库写入失败')

try:
    stock_comment_em_df = ak.stock_comment_em()
except:
    print('stock_comment_em_df出错了！！！！！')
else:
    stock_comment_em_df=stock_comment_em_df.add_prefix('stock_comment_em_')
    stock_comment_em_df['date']=startdate
try:
    pd.io.sql.to_sql(stock_comment_em_df,'stock_comment_em',con=conn,if_exists='append',index=False)
except:
    print('stock_comment_em_df数据库写入失败')


try:
    stock_hk_ggt_components_em_df = ak.stock_hk_ggt_components_em()
except:
    print('stock_hk_ggt_components_em_df出错了！！！！！')
else:
    stock_hk_ggt_components_em_df=stock_hk_ggt_components_em_df.add_prefix('stock_hk_ggt_components_em_')
    stock_hk_ggt_components_em_df['date']=startdate
try:
    pd.io.sql.to_sql(stock_hk_ggt_components_em_df,'stock_hk_ggt_components_em',con=conn,if_exists='append',index=False)
except:
    print('stock_hk_ggt_components_em_df数据库写入失败')

try:
    stock_em_hsgt_hold_stock_df_today = ak.stock_hsgt_hold_stock_em(market="北向", indicator="今日排行")
except:
    print('stock_em_hsgt_hold_stock_df_today出错了！！！！！')
else:
    stock_em_hsgt_hold_stock_df_today=stock_em_hsgt_hold_stock_df_today.add_prefix('stock_hsgt_hold_stock_em_today_')
    stock_em_hsgt_hold_stock_df_today['date']=startdate
try:
    pd.io.sql.to_sql(stock_em_hsgt_hold_stock_df_today,'stock_hsgt_hold_stock_em_today',con=conn,if_exists='append',index=False)
except:
    print('stock_em_hsgt_hold_stock_df_today数据库写入失败')

try:
    stock_em_hsgt_hold_stock_df_3day = ak.stock_hsgt_hold_stock_em(market="北向", indicator="3日排行")
except:
    print('stock_em_hsgt_hold_stock_df_3day出错了！！！！！')
else:
    stock_em_hsgt_hold_stock_df_3day=stock_em_hsgt_hold_stock_df_3day.add_prefix('stock_hsgt_hold_stock_em_3day_')
    stock_em_hsgt_hold_stock_df_3day['date']=startdate
try:
    pd.io.sql.to_sql(stock_em_hsgt_hold_stock_df_3day,'stock_hsgt_hold_stock_em_3day',con=conn,if_exists='append',index=False)
except:
    print('stock_em_hsgt_hold_stock_df_3day数据库写入失败')

try:
    stock_em_hsgt_hold_stock_df_5day = ak.stock_hsgt_hold_stock_em(market="北向", indicator="5日排行")
except:
    print('stock_em_hsgt_hold_stock_df_5day出错了！！！！！')
else:
    stock_em_hsgt_hold_stock_df_5day=stock_em_hsgt_hold_stock_df_5day.add_prefix('stock_hsgt_hold_stock_em_5day_')
    stock_em_hsgt_hold_stock_df_5day['date']=startdate
try:
    pd.io.sql.to_sql(stock_em_hsgt_hold_stock_df_5day,'stock_hsgt_hold_stock_em_5day',con=conn,if_exists='append',index=False)
except:
    print('stock_em_hsgt_hold_stock_df_5day数据库写入失败')

try:
    stock_em_hsgt_hold_stock_df_10day = ak.stock_hsgt_hold_stock_em(market="北向", indicator="10日排行")
except:
    print('stock_em_hsgt_hold_stock_df_10day出错了！！！！！')
else:
    stock_em_hsgt_hold_stock_df_10day=stock_em_hsgt_hold_stock_df_10day.add_prefix('stock_hsgt_hold_stock_em_10day_')
    stock_em_hsgt_hold_stock_df_10day['date']=startdate
try:
    pd.io.sql.to_sql(stock_em_hsgt_hold_stock_df_10day,'stock_hsgt_hold_stock_em_10day',con=conn,if_exists='append',index=False)
except:
    print('stock_em_hsgt_hold_stock_df_10day数据库写入失败')

try:
    stock_em_hsgt_hold_stock_df_month = ak.stock_hsgt_hold_stock_em(market="北向", indicator="月排行")
except:
    print('stock_em_hsgt_hold_stock_df_month出错了！！！！！')
else:
    stock_em_hsgt_hold_stock_df_month=stock_em_hsgt_hold_stock_df_month.add_prefix('stock_hsgt_hold_stock_em_month_')
    stock_em_hsgt_hold_stock_df_month['date']=startdate
try:
    pd.io.sql.to_sql(stock_em_hsgt_hold_stock_df_month,'stock_hsgt_hold_stock_em_month',con=conn,if_exists='append',index=False)
except:
    print('stock_em_hsgt_hold_stock_df_month数据库写入失败')

try:
    stock_tfp_em_df = ak.stock_tfp_em(date=sdate)
except:
    print('stock_tfp_em_df出错了！！！！！')
else:
    stock_tfp_em_df=stock_tfp_em_df.add_prefix('stock_tfp_em_')
    stock_tfp_em_df['date']=startdate
try:
    pd.io.sql.to_sql(stock_tfp_em_df,'stock_tfp_em',con=conn,if_exists='append',index=False)
except:
    print('stock_tfp_em_df数据库写入失败')
    


    
def tra(x):
    x=str(x)
    if(x[-1]=='万'):
        return float(x[:-1])*10000
    if(x[-1]=='亿'):
        return float(x[:-1])*100000000
    else:
        return x

def delper(x):
    x=str(x)
    if(x[-1]=='%'):
        return float(x[:-1])
    else:
        return float(x)
#需要补充3日，5日，10日
try:
    stock_fund_flow_individual_df_today = ak.stock_fund_flow_individual(symbol="即时")
    stock_fund_flow_individual_df_today['股票代码']=stock_fund_flow_individual_df_today['股票代码'].astype(str)
    stock_fund_flow_individual_df_today['股票代码']=stock_fund_flow_individual_df_today['股票代码'].map(lambda x:x.zfill(6))
    stock_fund_flow_individual_df_today['流入资金']=stock_fund_flow_individual_df_today['流入资金'].apply(tra)
    stock_fund_flow_individual_df_today['流出资金']=stock_fund_flow_individual_df_today['流出资金'].apply(tra)
    stock_fund_flow_individual_df_today['净额']=stock_fund_flow_individual_df_today['净额'].apply(tra)
    stock_fund_flow_individual_df_today['成交额']=stock_fund_flow_individual_df_today['成交额'].apply(tra)
except:
    print('stock_fund_flow_individual_df_today出错了！！！！！')
else:
    stock_fund_flow_individual_df_today=stock_fund_flow_individual_df_today.add_prefix('stock_fund_flow_individual_today_')
    stock_fund_flow_individual_df_today['date']=startdate
try:
    pd.io.sql.to_sql(stock_fund_flow_individual_df_today,'stock_fund_flow_individual_today',con=conn,if_exists='append',index=False)
except:
    print('stock_fund_flow_individual_df_today数据库写入失败')

    
try:
    stock_lhb_detail_em_df = ak.stock_lhb_detail_em(start_date=sdate, end_date=sdate)
    stock_lhb_detail_em_df.drop(columns=['名称','解读','收盘价','涨跌幅','换手率','流通市值','上榜原因'],inplace=True)
    stock_lhb_detail_em_df.rename(columns={'序号':'排行'},inplace=True)
    stock_lhb_detail_em_df=stock_lhb_detail_em_df.groupby('代码').agg(['sum'])
    stock_lhb_detail_em_df=stock_lhb_detail_em_df.reset_index('代码')
except:
    print('stock_lhb_detail_em_df出错了！！！！！')
else:
    stock_lhb_detail_em_df=stock_lhb_detail_em_df.add_prefix('stock_lhb_detail_em_')
    stock_lhb_detail_em_df['date']=startdate
try:
    pd.io.sql.to_sql(stock_lhb_detail_em_df,'stock_lhb_detail_em',con=conn,if_exists='append',index=False)
except:
    print('stock_lhb_detail_em_df数据库写入失败')
    
    
try:
    stock_lhb_stock_statistic_em_df = ak.stock_lhb_stock_statistic_em(symbol="近一月")
    stock_lhb_stock_statistic_em_df.rename(columns={'序号':'排行'},inplace=True)
except:
    print('stock_lhb_stock_statistic_em_df出错了！！！！！')
else:
    stock_lhb_stock_statistic_em_df=stock_lhb_stock_statistic_em_df.add_prefix('stock_lhb_stock_statistic_em_')
    stock_lhb_stock_statistic_em_df['date']=startdate
try:
    pd.io.sql.to_sql(stock_lhb_stock_statistic_em_df,'stock_lhb_stock_statistic_em',con=conn,if_exists='append',index=False)
except:
    print('stock_lhb_stock_statistic_em_df数据库写入失败')


daynum=[5,10,30]
#stock_lhb_ggtj_sina_df={}
for i in daynum:
    try:
        stock_lhb_ggtj_sina_df = ak.stock_lhb_ggtj_sina(recent_day=i)
        stock_lhb_ggtj_sina_df.drop(columns=['股票名称'],inplace=True)
        stock_lhb_ggtj_sina_df.rename(columns={'股票代码':'代码'},inplace=True)
    except:
        print('stock_lhb_ggtj_sina_df出错了！！！！！'+str(i)+'天')
    else:
        stock_lhb_ggtj_sina_df=stock_lhb_ggtj_sina_df.add_prefix('stock_lhb_stock_statistic_em_'+str(i)+'天')
        stock_lhb_ggtj_sina_df['date']=startdate
        print(stock_lhb_ggtj_sina_df)
    try:
        pd.io.sql.to_sql(stock_lhb_ggtj_sina_df,'stock_lhb_ggtj_sina_df_'+str(i)+'天',con=conn,if_exists='append',index=False)
    except:
        print('stock_lhb_ggtj_sina_df数据库写入失败'+str(i)+'天')
        

daynum=[5,10,30]
#stock_lhb_jgzz_sina_df={}
for i in daynum:
    try:
        stock_lhb_jgzz_sina_df = ak.stock_lhb_jgzz_sina(recent_day=i)
        stock_lhb_jgzz_sina_df.drop(columns=['股票名称'],inplace=True)
        stock_lhb_jgzz_sina_df.rename(columns={'股票代码':'代码'},inplace=True)
    except:
        print('stock_lhb_jgzz_sina_df出错了！！！！！'+str(i)+'天')
    else:
        stock_lhb_jgzz_sina_df=stock_lhb_jgzz_sina_df.add_prefix('stock_lhb_stock_statistic_em_'+str(i)+'天')
        stock_lhb_jgzz_sina_df['date']=startdate
        print(stock_lhb_jgzz_sina_df)
    try:
        pd.io.sql.to_sql(stock_lhb_jgzz_sina_df,'stock_lhb_jgzz_sina_df_'+str(i)+'天',con=conn,if_exists='append',index=False)
    except:
        print('stock_lhb_jgzz_sina_df数据库写入失败'+str(i)+'天')
        
        
try:
    stock_dzjy_mrtj_df = ak.stock_dzjy_mrtj(start_date=startdate, end_date=startdate)
    stock_dzjy_mrtj_df.drop(columns=['证券简称','交易日期','收盘价','涨跌幅','成交价','成交总额'],inplace=True)
    stock_dzjy_mrtj_df.rename(columns={'证券代码':'代码'},inplace=True)
except:
    print('stock_dzjy_mrtj_df出错了！！！！！')
else:
    stock_dzjy_mrtj_df=stock_dzjy_mrtj_df.add_prefix('stock_dzjy_mrtj_')
    stock_dzjy_mrtj_df['date']=startdate
try:
    pd.io.sql.to_sql(stock_dzjy_mrtj_df,'stock_dzjy_mrtj',con=conn,if_exists='append',index=False)
except:
    print('stock_dzjy_mrtj_df数据库写入失败')
    

try:
    stock_dzjy_hygtj_df = ak.stock_dzjy_hygtj(symbol='近一月')
    stock_dzjy_hygtj_df.rename(columns={'证券代码':'代码'},inplace=True)
except:
    print('stock_dzjy_hygtj_df出错了！！！！！')
else:
    stock_dzjy_hygtj_df=stock_dzjy_hygtj_df.add_prefix('stock_dzjy_hygtj_')
    stock_dzjy_hygtj_df['date']=startdate
try:
    pd.io.sql.to_sql(stock_dzjy_hygtj_df,'stock_dzjy_hygtj',con=conn,if_exists='append',index=False)
except:
    print('stock_dzjy_hygtj_df数据库写入失败')
    
    
try:
    stock_hot_follow_xq_zrm_df = ak.stock_hot_follow_xq(symbol='最热门')
    stock_hot_follow_xq_zrm_df.rename(columns={'证券代码':'代码'},inplace=True)
except:
    print('stock_hot_follow_xq_zrm_df出错了！！！！！')
else:
    stock_hot_follow_xq_zrm_df=stock_hot_follow_xq_zrm_df.add_prefix('stock_hot_follow_xq_zrm_')
    stock_hot_follow_xq_zrm_df['date']=startdate
try:
    pd.io.sql.to_sql(stock_hot_follow_xq_zrm_df,'stock_hot_follow_xq_zrm',con=conn,if_exists='append',index=False)
except:
    print('stock_hot_follow_xq_zrm_df数据库写入失败')
    

try:
    stock_hot_follow_xq_bzxz_df = ak.stock_hot_follow_xq(symbol='本周新增')
    stock_hot_follow_xq_bzxz_df.rename(columns={'证券代码':'代码'},inplace=True)
except:
    print('stock_hot_follow_xq_bzxz_df出错了！！！！！')
else:
    stock_hot_follow_xq_bzxz_df=stock_hot_follow_xq_bzxz_df.add_prefix('stock_hot_follow_xq_bzxz_')
    stock_hot_follow_xq_bzxz_df['date']=startdate
try:
    pd.io.sql.to_sql(stock_hot_follow_xq_bzxz_df,'stock_hot_follow_xq_bzxz',con=conn,if_exists='append',index=False)
except:
    print('stock_hot_follow_xq_bzxz_df数据库写入失败')
    
    
try:
    stock_hot_tweet_xq_zrm_df = ak.stock_hot_tweet_xq(symbol='最热门')
    stock_hot_tweet_xq_zrm_df.rename(columns={'证券代码':'代码'},inplace=True)
except:
    print('stock_hot_tweet_xq_zrm_df出错了！！！！！')
else:
    stock_hot_tweet_xq_zrm_df=stock_hot_tweet_xq_zrm_df.add_prefix('stock_hot_tweet_xq_zrm_')
    stock_hot_tweet_xq_zrm_df['date']=startdate
try:
    pd.io.sql.to_sql(stock_hot_tweet_xq_zrm_df,'stock_hot_tweet_xq_zrm',con=conn,if_exists='append',index=False)
except:
    print('stock_hot_tweet_xq_zrm_df数据库写入失败')


try:
    stock_hot_tweet_xq_bzxz_df = ak.stock_hot_tweet_xq(symbol='本周新增')
    stock_hot_tweet_xq_bzxz_df.rename(columns={'证券代码':'代码'},inplace=True)
except:
    print('stock_hot_tweet_xq_bzxz_df出错了！！！！！')
else:
    stock_hot_tweet_xq_bzxz_df=stock_hot_tweet_xq_bzxz_df.add_prefix('stock_hot_tweet_xq_bzxz_')
    stock_hot_tweet_xq_bzxz_df['date']=startdate
try:
    pd.io.sql.to_sql(stock_hot_tweet_xq_bzxz_df,'stock_hot_tweet_xq_bzxz',con=conn,if_exists='append',index=False)
except:
    print('stock_hot_tweet_xq_bzxz_df数据库写入失败')
    
try:
    stock_hot_deal_xq_zrm_df = ak.stock_hot_deal_xq(symbol='最热门')
    stock_hot_deal_xq_zrm_df.rename(columns={'证券代码':'代码'},inplace=True)
except:
    print('stock_hot_deal_xq_zrm_df出错了！！！！！')
else:
    stock_hot_deal_xq_zrm_df=stock_hot_deal_xq_zrm_df.add_prefix('stock_hot_deal_xq_zrm_')
    stock_hot_deal_xq_zrm_df['date']=startdate
try:
    pd.io.sql.to_sql(stock_hot_deal_xq_zrm_df,'stock_hot_deal_xq_zrm',con=conn,if_exists='append',index=False)
except:
    print('stock_hot_deal_xq_zrm_df数据库写入失败')
    
try:
    stock_hot_deal_xq_bzxz_df = ak.stock_hot_deal_xq(symbol='本周新增')
    stock_hot_deal_xq_bzxz_df.rename(columns={'证券代码':'代码'},inplace=True)
except:
    print('stock_hot_deal_xq_bzxz_df出错了！！！！！')
else:
    stock_hot_deal_xq_bzxz_df=stock_hot_deal_xq_bzxz_df.add_prefix('stock_hot_deal_xq_bzxz_')
    stock_hot_deal_xq_bzxz_df['date']=startdate
try:
    pd.io.sql.to_sql(stock_hot_deal_xq_bzxz_df,'stock_hot_deal_xq_bzxz',con=conn,if_exists='append',index=False)
except:
    print('stock_hot_deal_xq_bzxz_df数据库写入失败')
    
    
def to_rank_float(strs):
    #str.replace('-', '-1')
    #strs=str(strs)
    strs=str(strs)
    strs=strs.split('/')
    if len(strs)>=2:
        flo=float(strs[0])/float(strs[1])
    else:
        flo=None
    return flo

try:
    stock_hot_rank_wc_df = ak.stock_hot_rank_wc(date=sdate)
    stock_hot_rank_wc_df.rename(columns={'证券代码':'代码'},inplace=True)
    stock_hot_rank_wc_df['个股热度排名']=stock_hot_rank_wc_df['个股热度排名'].apply(to_rank_float)
except:
    print('stock_hot_rank_wc_df出错了！！！！！')
else:
    stock_hot_rank_wc_df=stock_hot_rank_wc_df.add_prefix('stock_hot_rank_wc_')
    stock_hot_rank_wc_df['date']=startdate
try:
    pd.io.sql.to_sql(stock_hot_rank_wc_df,'stock_hot_rank_wc',con=conn,if_exists='append',index=False)
except:
    print('stock_hot_rank_wc_df数据库写入失败')
    
    
stock_individual_fund_flow_rank_indicator=["今日","3日","5日","10日"]
for i in stock_individual_fund_flow_rank_indicator:
    try:
        stock_individual_fund_flow_rank_df = ak.stock_individual_fund_flow_rank(indicator=i)
        stock_individual_fund_flow_rank_df.rename(columns={'股票代码':'代码'},inplace=True)
    except:
        print('stock_individual_fund_flow_rank_df出错了！！！！！'+i)
    else:
        stock_individual_fund_flow_rank_df=stock_individual_fund_flow_rank_df.add_prefix('stock_lhb_stock_statistic_em_'+i)
        stock_individual_fund_flow_rank_df['date']=startdate
        print(stock_individual_fund_flow_rank_df)
    try:
        pd.io.sql.to_sql(stock_individual_fund_flow_rank_df,'stock_individual_fund_flow_rank_df_'+i,con=conn,if_exists='append',index=False)
    except:
        print('stock_individual_fund_flow_rank_df数据库写入失败'+i)

try:
    stock_zh_a_gdhs_df = ak.stock_zh_a_gdhs(symbol="最新")
    stock_zh_a_gdhs_df.rename(columns={'证券代码':'代码'},inplace=True)
except:
    print('stock_zh_a_gdhs_df出错了！！！！！')
else:
    stock_zh_a_gdhs_df=stock_zh_a_gdhs_df.add_prefix('stock_zh_a_gdhs_')
    stock_zh_a_gdhs_df['date']=startdate
try:
    pd.io.sql.to_sql(stock_zh_a_gdhs_df,'stock_zh_a_gdhs',con=conn,if_exists='append',index=False)
except:
    print('stock_zh_a_gdhs_df数据库写入失败')

try:
    stock_hot_rank_em_df = ak.stock_hot_rank_em()
    stock_hot_rank_em_df.rename(columns={'证券代码':'代码'},inplace=True)
except:
    print('stock_hot_rank_em_df出错了！！！！！')
else:
    stock_hot_rank_em_df=stock_hot_rank_em_df.add_prefix('stock_hot_rank_em_')
    stock_hot_rank_em_df['date']=startdate
try:
    pd.io.sql.to_sql(stock_hot_rank_em_df,'stock_hot_rank_em',con=conn,if_exists='append',index=False)
except:
    print('stock_hot_rank_em_df数据库写入失败')
    
try:
    stock_lhb_jgmx_sina_df = ak.stock_lhb_jgmx_sina()
    stock_lhb_jgmx_sina_df.rename(columns={'股票代码':'代码'},inplace=True)
except:
    print('stock_lhb_jgmx_sina_df出错了！！！！！')
else:
    stock_lhb_jgmx_sina_df=stock_lhb_jgmx_sina_df.add_prefix('stock_lhb_jgmx_sina_')
    stock_lhb_jgmx_sina_df['date']=startdate
try:
    pd.io.sql.to_sql(stock_lhb_jgmx_sina_df,'stock_lhb_jgmx_sina',con=conn,if_exists='append',index=False)
except:
    print('stock_lhb_jgmx_sina_df数据库写入失败')
    
try:
    stock_dzjy_mrmx_df = ak.stock_dzjy_mrmx(symbol='A股', start_date=sdate, end_date=edate)
    stock_dzjy_mrmx_df.rename(columns={'证券代码':'代码'},inplace=True)
except:
    print('stock_dzjy_mrmx_df出错了！！！！！')
else:
    stock_dzjy_mrmx_df=stock_dzjy_mrmx_df.add_prefix('stock_dzjy_mrmx_')
    stock_dzjy_mrmx_df['date']=startdate
try:
    pd.io.sql.to_sql(stock_dzjy_mrmx_df,'stock_dzjy_mrmx',con=conn,if_exists='append',index=False)
except:
    print('stock_dzjy_mrmx_df数据库写入失败')
    

try:
    stock_dxsyl_em_df = ak.stock_dxsyl_em()
    stock_dxsyl_em_df.rename(columns={'股票代码':'代码'},inplace=True)
except:
    print('stock_dxsyl_em_df出错了！！！！！')
else:
    stock_dxsyl_em_df=stock_dxsyl_em_df.add_prefix('stock_dxsyl_em_')
    stock_dxsyl_em_df['date']=startdate
try:
    pd.io.sql.to_sql(stock_dxsyl_em_df,'stock_dxsyl_em',con=conn,if_exists='append',index=False)
except:
    print('stock_dxsyl_em_df数据库写入失败')

try:
    stock_fund_flow_big_deal_df = ak.stock_fund_flow_big_deal()
    stock_fund_flow_big_deal_df.rename(columns={'股票代码':'代码'},inplace=True)
except:
    print('stock_fund_flow_big_deal_df出错了！！！！！')
else:
    stock_fund_flow_big_deal_df=stock_fund_flow_big_deal_df.add_prefix('stock_fund_flow_big_deal_')
    stock_fund_flow_big_deal_df['date']=startdate
try:
    pd.io.sql.to_sql(stock_fund_flow_big_deal_df,'stock_fund_flow_big_deal',con=conn,if_exists='append',index=False)
except:
    print('stock_fund_flow_big_deal_df数据库写入失败')    

stock_changes_em_df_all = ak.stock_zh_a_spot_em()[['序号','代码']]
stock_changes_em_symbol=['火箭发射','快速反弹','大笔买入','封涨停板','打开跌停板','有大买盘','竞价上涨','高开5日线','60日新高','60日大幅上涨','加速下跌','高台跳水','大笔卖出','封跌停板','打开涨停板','有大卖盘','竞价下跌','低开5日线','60日新低','60日大幅下跌']
for i in stock_changes_em_symbol:
    try:
        stock_changes_em_df = ak.stock_changes_em(symbol=i)
        stock_changes_em_df=stock_changes_em_df.groupby('代码').agg({'名称':['count']})
        stock_changes_em_df.columns = stock_changes_em_df.columns.map('_'.join)
        stock_changes_em_df.rename(columns={'名称_count':'stock_changes_em_'+i},inplace=True)
        #需要左连接
        stock_changes_em_df_all=stock_changes_em_df_all.merge(stock_changes_em_df,on='代码',how='left')
        #print(stock_changes_em_df_all)
    except:
        print('stock_changes_em_df！！！！！'+i)
try:
    stock_changes_em_df_all['date']=startdate
    pd.io.sql.to_sql(stock_changes_em_df_all,'stock_changes_em_df_all',con=conn,if_exists='append',index=False)
except:
    print('stock_changes_em_df_all数据库写入失败')

#获取东方财富板块数据，需匹配板块行情数据
try:
    stock_board_industry_name_em_df = ak.stock_board_industry_name_em()
    #stock_board_industry_name_em_df.rename(columns={'证券代码':'代码'},inplace=True)
except:
    print('stock_board_industry_name_em_df出错了！！！！！')
else:
    stock_board_industry_name_em_df=stock_board_industry_name_em_df.add_prefix('stock_board_industry_name_em_')
    stock_board_industry_name_em_df['date']=startdate
try:
    pd.io.sql.to_sql(stock_board_industry_name_em_df,'stock_board_industry_name_em',con=conn,if_exists='append',index=False)
except:
    print('stock_board_industry_name_em_df数据库写入失败')
    

try:
    stock_gpzy_pledge_ratio_em_df = ak.stock_gpzy_pledge_ratio_em()
except:
    print('stock_gpzy_pledge_ratio_em_df出错了！！！！！')
else:
    stock_gpzy_pledge_ratio_em_df=stock_gpzy_pledge_ratio_em_df.add_prefix('stock_gpzy_pledge_ratio_em_')
    stock_gpzy_pledge_ratio_em_df['date']=startdate
try:
    pd.io.sql.to_sql(stock_gpzy_pledge_ratio_em_df,'stock_gpzy_pledge_ratio_em',con=conn,if_exists='append',index=False)
except:
    print('stock_gpzy_pledge_ratio_em_df数据库写入失败')
    

#技术指标
cxgsymbol=["创月新高", "半年新高", "一年新高", "历史新高"]
#stock_rank_cxg_ths_df={}
for i in cxgsymbol:
    try:
        stock_rank_cxg_ths_df = ak.stock_rank_cxg_ths(symbol=i)
        stock_rank_cxg_ths_df.rename(columns={'股票代码':'代码'},inplace=True)
    except:
        print('stock_rank_cxg_ths_df出错了！！！！！'+i)
    else:
        stock_rank_cxg_ths_df=stock_rank_cxg_ths_df.add_prefix('stock_lhb_stock_statistic_em_'+i)
        stock_rank_cxg_ths_df['date']=startdate
        print(stock_rank_cxg_ths_df)
    try:
        pd.io.sql.to_sql(stock_rank_cxg_ths_df,'stock_rank_cxg_ths_df_'+i,con=conn,if_exists='append',index=False)
    except:
        print('stock_rank_cxg_ths_df数据库写入失败'+i)



#创新高/新低      
cxdsymbol=["创月新低", "半年新低", "一年新低", "历史新低"]
for i in cxdsymbol:
    try:
        stock_rank_cxd_ths_df = ak.stock_rank_cxd_ths(symbol=i)
        stock_rank_cxd_ths_df.rename(columns={'股票代码':'代码'},inplace=True)
    except:
        print('stock_rank_cxd_ths_df出错了！！！！！'+i)
    else:
        stock_rank_cxd_ths_df=stock_rank_cxd_ths_df.add_prefix('stock_lhb_stock_statistic_em_'+i)
        stock_rank_cxd_ths_df['date']=startdate
        print(stock_rank_cxd_ths_df)
    try:
        pd.io.sql.to_sql(stock_rank_cxd_ths_df,'stock_rank_cxd_ths_df_'+i,con=conn,if_exists='append',index=False)
    except:
        print('stock_rank_cxd_ths_df数据库写入失败'+i)


#连续上涨，连续下跌
try:
    stock_rank_lxsz_ths_df = ak.stock_rank_lxsz_ths()
    stock_rank_lxsz_ths_df.rename(columns={'证券代码':'代码'},inplace=True)
except:
    print('stock_rank_lxsz_ths_df出错了！！！！！')
else:
    stock_rank_lxsz_ths_df=stock_rank_lxsz_ths_df.add_prefix('stock_rank_lxsz_ths_')
    stock_rank_lxsz_ths_df['date']=startdate
try:
    pd.io.sql.to_sql(stock_rank_lxsz_ths_df,'stock_rank_lxsz_ths',con=conn,if_exists='append',index=False)
except:
    print('stock_rank_lxsz_ths_df数据库写入失败')


try:
    stock_rank_lxxd_ths_df = ak.stock_rank_lxxd_ths()
    stock_rank_lxxd_ths_df.rename(columns={'证券代码':'代码'},inplace=True)
except:
    print('stock_rank_lxxd_ths_df出错了！！！！！')
else:
    stock_rank_lxxd_ths_df=stock_rank_lxxd_ths_df.add_prefix('stock_rank_lxxd_ths_')
    stock_rank_lxxd_ths_df['date']=startdate
try:
    pd.io.sql.to_sql(stock_rank_lxxd_ths_df,'stock_rank_lxxd_ths',con=conn,if_exists='append',index=False)
except:
    print('stock_rank_lxxd_ths_df数据库写入失败')
    
    
#持续放量/缩量
try:
    stock_rank_cxfl_ths_df = ak.stock_rank_cxfl_ths()
    stock_rank_cxfl_ths_df.rename(columns={'证券代码':'代码'},inplace=True)
except:
    print('stock_rank_cxfl_ths_df出错了！！！！！')
else:
    stock_rank_cxfl_ths_df=stock_rank_cxfl_ths_df.add_prefix('stock_rank_cxfl_ths_')
    stock_rank_cxfl_ths_df['date']=startdate
try:
    pd.io.sql.to_sql(stock_rank_cxfl_ths_df,'stock_rank_cxfl_ths',con=conn,if_exists='append',index=False)
except:
    print('stock_rank_cxfl_ths_df数据库写入失败')
    
try:
    stock_rank_cxsl_ths_df = ak.stock_rank_cxsl_ths()
    stock_rank_cxsl_ths_df.rename(columns={'证券代码':'代码'},inplace=True)
except:
    print('stock_rank_cxsl_ths_df出错了！！！！！')
else:
    stock_rank_cxsl_ths_df=stock_rank_cxsl_ths_df.add_prefix('stock_rank_cxsl_ths_')
    stock_rank_cxsl_ths_df['date']=startdate
try:
    pd.io.sql.to_sql(stock_rank_cxsl_ths_df,'stock_rank_cxsl_ths',con=conn,if_exists='append',index=False)
except:
    print('stock_rank_cxsl_ths_df数据库写入失败')
    
    
#量价齐升/齐跌
try:
    stock_rank_ljqs_ths_df = ak.stock_rank_ljqs_ths()
    stock_rank_ljqs_ths_df.rename(columns={'证券代码':'代码'},inplace=True)
except:
    print('stock_rank_ljqs_ths_df出错了！！！！！')
else:
    stock_rank_ljqs_ths_df=stock_rank_ljqs_ths_df.add_prefix('stock_rank_ljqs_ths_')
    stock_rank_ljqs_ths_df['date']=startdate
try:
    pd.io.sql.to_sql(stock_rank_ljqs_ths_df,'stock_rank_ljqs_ths',con=conn,if_exists='append',index=False)
except:
    print('stock_rank_ljqs_ths_df数据库写入失败')

try:
    stock_rank_ljqd_ths_df = ak.stock_rank_ljqd_ths()
    stock_rank_ljqd_ths_df.rename(columns={'证券代码':'代码'},inplace=True)
except:
    print('stock_rank_ljqd_ths_df出错了！！！！！')
else:
    stock_rank_ljqd_ths_df=stock_rank_ljqd_ths_df.add_prefix('stock_rank_ljqd_ths_')
    stock_rank_ljqd_ths_df['date']=startdate
try:
    pd.io.sql.to_sql(stock_rank_ljqd_ths_df,'stock_rank_ljqd_ths',con=conn,if_exists='append',index=False)
except:
    print('stock_rank_ljqd_ths_df数据库写入失败')
    
    
tpsymbol=["5日均线", "10日均线", "20日均线", "30日均线", "60日均线", "90日均线"]
for i in tpsymbol:
    try:
        stock_rank_xstp_ths_df = ak.stock_rank_xstp_ths(symbol=i)
        stock_rank_xstp_ths_df.rename(columns={'股票代码':'代码'},inplace=True)
    except:
        print('stock_rank_xstp_ths_df出错了！！！！！'+i)
    else:
        stock_rank_xstp_ths_df=stock_rank_xstp_ths_df.add_prefix('stock_lhb_stock_statistic_em_'+i)
        stock_rank_xstp_ths_df['date']=startdate
        print(stock_rank_xstp_ths_df)
    try:
        pd.io.sql.to_sql(stock_rank_xstp_ths_df,'stock_rank_xstp_ths_df_'+i,con=conn,if_exists='append',index=False)
    except:
        print('stock_rank_xstp_ths_df数据库写入失败'+i)
        
tpsymbol=["5日均线", "10日均线", "20日均线", "30日均线", "60日均线", "90日均线"]
for i in tpsymbol:
    try:
        stock_rank_xxtp_ths_df = ak.stock_rank_xxtp_ths(symbol=i)
        stock_rank_xxtp_ths_df.rename(columns={'股票代码':'代码'},inplace=True)
    except:
        print('stock_rank_xxtp_ths_df出错了！！！！！'+i)
    else:
        stock_rank_xxtp_ths_df=stock_rank_xxtp_ths_df.add_prefix('stock_lhb_stock_statistic_em_'+i)
        stock_rank_xxtp_ths_df['date']=startdate
        print(stock_rank_xxtp_ths_df)
    try:
        pd.io.sql.to_sql(stock_rank_xxtp_ths_df,'stock_rank_xxtp_ths_df_'+i,con=conn,if_exists='append',index=False)
    except:
        print('stock_rank_xxtp_ths_df数据库写入失败'+i)

# %%
#关闭
conn.dispose()
#提交测试

# %%
#需遍历执行
#获取全量股票代码
StockList = ak.stock_zh_a_spot_em()['代码'].values.tolist()
StockList_add_prefix=[]
for i in range(0,len(StockList)):
    temp=StockList[i]
    if temp[:1]=="6":
        StockList_add_prefix.append('SH'+StockList[i])
    elif temp[:1]=="0" or temp[:1]=="3" :
        StockList_add_prefix.append('SZ'+StockList[i])


stock_comment_detail_zlkp_jgcyd_em_df_all=pd.DataFrame()
for i in StockList:
    try:
        stock_comment_detail_zlkp_jgcyd_em_df = ak.stock_comment_detail_zlkp_jgcyd_em(symbol=i)
        stock_comment_detail_zlkp_jgcyd_em_df.rename(columns={'value':'stock_comment_detail_zlkp_jgcyd_em_value'},inplace=True)
        stock_comment_detail_zlkp_jgcyd_em_df['代码']=i
    except:
        #print('i stock_comment_detail_zlkp_jgcyd_em_df出错了！！！！！')
        continue
    else:
        stock_comment_detail_zlkp_jgcyd_em_df_all=stock_comment_detail_zlkp_jgcyd_em_df_all.append(stock_comment_detail_zlkp_jgcyd_em_df,ignore_index=True)
try:
    #stock_comment_detail_zlkp_jgcyd_em_df_all=stock_comment_detail_zlkp_jgcyd_em_df_all.add_prefix('stock_comment_detail_zlkp_jgcyd_em_')
    pd.io.sql.to_sql(stock_comment_detail_zlkp_jgcyd_em_df_all,'stock_comment_detail_zlkp_jgcyd_em',con=conn,if_exists='replace',index=False)
except:
    print('stock_comment_detail_zlkp_jgcyd_em_df数据库写入失败')

    
stock_comment_detail_zhpj_lspf_em_df_all=pd.DataFrame()
for i in StockList:
    #i=str(i).zfill(6)
    try:
        stock_comment_detail_zhpj_lspf_em_df = ak.stock_comment_detail_zhpj_lspf_em(symbol=i)
        stock_comment_detail_zhpj_lspf_em_df.rename(columns={'评分':'stock_comment_detail_zhpj_lspf_em_评分'},inplace=True)
        stock_comment_detail_zhpj_lspf_em_df.drop(columns=['股价'],inplace=True)
        stock_comment_detail_zhpj_lspf_em_df['代码']=i
    except:
        #print('i stock_comment_detail_zhpj_lspf_em_df出错了！！！！！')
        continue
    else:
        stock_comment_detail_zhpj_lspf_em_df_all=stock_comment_detail_zhpj_lspf_em_df_all.append(stock_comment_detail_zhpj_lspf_em_df,ignore_index=True)
try:
    #stock_comment_detail_zhpj_lspf_em_df_all.add_prefix('stock_comment_detail_zhpj_lspf_em_')
    pd.io.sql.to_sql(stock_comment_detail_zhpj_lspf_em_df_all,'stock_comment_detail_zhpj_lspf_em',con=conn,if_exists='replace',index=False)
except:
    print('stock_comment_detail_zhpj_lspf_em_df数据库写入失败')
    
stock_comment_detail_scrd_focus_em_df_all=pd.DataFrame()
for i in StockList:
    #i=str(i).zfill(6)
    try:
        stock_comment_detail_scrd_focus_em_df = ak.stock_comment_detail_scrd_focus_em(symbol=i)
        stock_comment_detail_scrd_focus_em_df.rename(columns={'用户关注指数':'stock_comment_detail_zhpj_lspf_em_用户关注指数'},inplace=True)
        stock_comment_detail_scrd_focus_em_df.drop(columns=['收盘价'],inplace=True)
        stock_comment_detail_scrd_focus_em_df['代码']=i
    except:
        #print('i stock_comment_detail_scrd_focus_em_df出错了！！！！！')
        continue
    else:
        stock_comment_detail_scrd_focus_em_df_all=stock_comment_detail_scrd_focus_em_df_all.append(stock_comment_detail_scrd_focus_em_df,ignore_index=True)
try:
    #stock_comment_detail_scrd_focus_em_df_all.add_prefix('stock_comment_detail_scrd_focus_em_')
    pd.io.sql.to_sql(stock_comment_detail_scrd_focus_em_df_all,'stock_comment_detail_scrd_focus_em',con=conn,if_exists='replace',index=False)
except:
    print('stock_comment_detail_scrd_focus_em_df数据库写入失败')
    
    
stock_comment_detail_scrd_desire_daily_em_df_all=pd.DataFrame()
for i in StockList:
    #i=str(i).zfill(6)
    try:
        stock_comment_detail_scrd_desire_daily_em_df = ak.stock_comment_detail_scrd_desire_daily_em(symbol=i)
        stock_comment_detail_scrd_desire_daily_em_df.rename(columns={'当日意愿下降':'stock_comment_detail_scrd_desire_daily_em_当日意愿下降'},inplace=True)
        stock_comment_detail_scrd_desire_daily_em_df.rename(columns={'五日累计意愿':'stock_comment_detail_scrd_desire_daily_em_五日累计意愿'},inplace=True)
        stock_comment_detail_scrd_desire_daily_em_df['代码']=i
    except:
        #print('i stock_comment_detail_scrd_desire_daily_em_df出错了！！！！！')
        continue
    else:
        stock_comment_detail_scrd_desire_daily_em_df_all=stock_comment_detail_scrd_desire_daily_em_df_all.append(stock_comment_detail_scrd_desire_daily_em_df,ignore_index=True)
try:
    #stock_comment_detail_scrd_desire_daily_em_df_all.add_prefix('stock_comment_detail_scrd_desire_daily_em_')
    pd.io.sql.to_sql(stock_comment_detail_scrd_desire_daily_em_df_all,'stock_comment_detail_scrd_desire_daily_em',con=conn,if_exists='replace',index=False)
except:
    print('stock_comment_detail_scrd_desire_daily_em_df数据库写入失败')
    
    
stock_comment_detail_scrd_cost_em_df_all=pd.DataFrame()
for i in StockList:
    #i=str(i).zfill(6)
    try:
        stock_comment_detail_scrd_cost_em_df = ak.stock_comment_detail_scrd_cost_em(symbol=i)
        stock_comment_detail_scrd_cost_em_df.rename(columns={'市场成本':'stock_comment_detail_scrd_cost_em_市场成本'},inplace=True)
        stock_comment_detail_scrd_cost_em_df.rename(columns={'5日市场成本':'stock_comment_detail_scrd_cost_em_5日市场成本'},inplace=True)
        stock_comment_detail_scrd_cost_em_df['代码']=i
    except:
        #print('i stock_comment_detail_scrd_cost_em_df出错了！！！！！')
        continue
    else:
        stock_comment_detail_scrd_cost_em_df_all=stock_comment_detail_scrd_cost_em_df_all.append(stock_comment_detail_scrd_cost_em_df,ignore_index=True)
try:
    #stock_comment_detail_scrd_cost_em_df_all.add_prefix('stock_comment_detail_scrd_cost_em_')
    pd.io.sql.to_sql(stock_comment_detail_scrd_cost_em_df_all,'stock_comment_detail_scrd_cost_em',con=conn,if_exists='replace',index=False)
except:
    print('stock_comment_detail_scrd_cost_em_df数据库写入失败')
    
#沪深港通持股-个股 研究下怎么用
stock_hsgt_individual_em_df_all=pd.DataFrame()
for i in StockList:
    try:
        stock_hsgt_individual_em_df = ak.stock_hsgt_individual_em(stock=i)
        stock_hsgt_individual_em_df_all=stock_hsgt_individual_em_df_all.add_prefix('stock_hsgt_individual_em_')
        stock_hsgt_individual_em_df['代码']=i
    except:
        #print('i stock_hsgt_individual_em_df出错了！！！！！')
        continue
    else:
        stock_hsgt_individual_em_df_all=stock_hsgt_individual_em_df_all.append(stock_hsgt_individual_em_df,ignore_index=True)
try:
    #stock_hsgt_individual_em_df_all=stock_hsgt_individual_em_df_all.add_prefix('stock_hsgt_individual_em_')
    pd.io.sql.to_sql(stock_hsgt_individual_em_df_all,'stock_hsgt_individual_em',con=conn,if_exists='replace',index=False)
except:
    print('stock_hsgt_individual_em_df数据库写入失败')

    
import time
start_time = time.time()
StockList_add_prefix=[]
for i in range(0,len(StockList)):
    temp=StockList[i]
    if temp[:1]=="6":
        StockList_add_prefix.append('SH'+StockList[i])
    elif temp[:1]=="0" or temp[:1]=="3" :
        StockList_add_prefix.append('SZ'+StockList[i])
stock_hot_rank_detail_em_df_all=pd.DataFrame()
for i in StockList_add_prefix:
    #i=str(i).zfill(6)
    try:
        stock_hot_rank_detail_em_df = ak.stock_hot_rank_detail_em(symbol=i)
        stock_hot_rank_detail_em_df.rename(columns={'时间':'date'},inplace=True)
        stock_hot_rank_detail_em_df.rename(columns={'排名':'stock_hot_rank_detail_em_排名'},inplace=True)
        stock_hot_rank_detail_em_df.drop(columns=['证券代码'],inplace=True)
        stock_hot_rank_detail_em_df.rename(columns={'新晋粉丝':'stock_hot_rank_detail_em_新晋粉丝'},inplace=True)
        stock_hot_rank_detail_em_df.rename(columns={'铁杆粉丝':'stock_hot_rank_detail_em_铁杆粉丝'},inplace=True)
        stock_hot_rank_detail_em_df['代码']=i[2:]
    except:
        #print('i stock_hot_rank_detail_em_df出错了！！！！！')
        continue
    else:
        stock_hot_rank_detail_em_df_all=stock_hot_rank_detail_em_df_all.append(stock_hot_rank_detail_em_df,ignore_index=True)
try:
    #stock_hot_rank_detail_em_df_all.add_prefix('stock_hot_rank_detail_em_')
    pd.io.sql.to_sql(stock_hot_rank_detail_em_df_all,'stock_hot_rank_detail_em',con=conn,if_exists='replace',index=False)
except:
    print('stock_hot_rank_detail_em_df数据库写入失败')
print(stock_hot_rank_detail_em_df_all)
end_time = time.time()
print("程序执行时间：", end_time - start_time, "秒")



    
#暂时不用
#板块相关
#行业板块可以通过 ak.stock_board_industry_name_em() 接口获取
stock_hsgt_board_rank_em
stock_fund_flow_industry
stock_sector_fund_flow_rank
try:
    stock_gpzy_industry_data_em_df = ak.stock_gpzy_industry_data_em()
except:
    print('stock_gpzy_industry_data_em_df出错了！！！！！')
else:
    stock_gpzy_industry_data_em_df=stock_gpzy_industry_data_em_df.add_prefix('stock_gpzy_industry_data_em_')
    stock_gpzy_industry_data_em_df['date']=startdate
try:
    pd.io.sql.to_sql(stock_gpzy_industry_data_em_df,'stock_gpzy_industry_data_em',con=conn,if_exists='append',index=False)
except:
    print('stock_gpzy_industry_data_em_df数据库写入失败')



#一个季度获取一次
stock_yjbb_em_df = ak.stock_yjbb_em(date="20220331")
print(stock_yjbb_em_df)
stock_yjkb_em_df = ak.stock_yjkb_em(date="20200331")
print(stock_yjkb_em_df)
stock_yjyg_em_df = ak.stock_yjyg_em(date="20190331")
print(stock_yjyg_em_df)
stock_zcfz_em_df = ak.stock_zcfz_em(date="20220331")
print(stock_zcfz_em_df)
stock_lrb_em_df = ak.stock_lrb_em(date="20220331")
print(stock_lrb_em_df)
stock_xjll_em_df = ak.stock_xjll_em(date="20200331")
print(stock_xjll_em_df)
stock_fhps_em_df = ak.stock_fhps_em(date="20201231")
print(stock_fhps_em_df)

    


    
    
    

#接口错误但信息重要
stock_hsgt_stock_statistics_em_df = ak.stock_hsgt_stock_statistics_em(symbol="北向持股", start_date="20211027", end_date="20211027")
print(stock_hsgt_stock_statistics_em_df)
stock_hsgt_individual_detail_em_df = ak.stock_hsgt_individual_detail_em(symbol="002008", start_date="20210830",end_date="20211026")
print(stock_hsgt_individual_detail_em_df)
stock_sector_fund_flow_summary_df = ak.stock_sector_fund_flow_summary(symbol="电源设备", indicator="今日")
print(stock_sector_fund_flow_summary_df)
stock_profit_forecast_em_df = ak.stock_profit_forecast_em()
print(stock_profit_forecast_em_df)
stock_restricted_release_detail_em_df = ak.stock_restricted_release_detail_em(start_date="20221202", end_date="20221204")
print(stock_restricted_release_detail_em_df)
stock_zt_pool_em_df = ak.stock_zt_pool_em(date='20210525')
print(stock_zt_pool_em_df)
stock_zt_pool_em_df = ak.stock_zt_pool_em(date='20210525')
print(stock_zt_pool_em_df)
stock_zt_pool_strong_em_df = ak.stock_zt_pool_strong_em(date='20210521')
print(stock_zt_pool_strong_em_df)
stock_zt_pool_zbgc_em_df = ak.stock_zt_pool_zbgc_em(date='20210525')
print(stock_zt_pool_zbgc_em_df)
stock_zt_pool_dtgc_em_df = ak.stock_zt_pool_dtgc_em(date='20220425')
print(stock_zt_pool_dtgc_em_df)
stock_zt_pool_dtgc_em_df = ak.stock_zt_pool_dtgc_em(date='20220425')
print(stock_zt_pool_dtgc_em_df)
stock_hot_search_baidu_df = ak.stock_hot_search_baidu(symbol="A股", date="20221014", time="18")
print(stock_hot_search_baidu_df)
try:
    stock_lhb_jgstatistic_em_df = ak.stock_lhb_jgstatistic_em()
    stock_lhb_jgstatistic_em_df.rename(columns={'证券代码':'代码'},inplace=True)
except:
    print('stock_lhb_jgstatistic_em_df出错了！！！！！')
else:
    stock_lhb_jgstatistic_em_df=stock_lhb_jgstatistic_em_df.add_prefix('stock_lhb_jgstatistic_em_')
    stock_lhb_jgstatistic_em_df['date']=startdate
try:
    pd.io.sql.to_sql(stock_lhb_jgstatistic_em_df,'stock_lhb_jgstatistic_em',con=conn,if_exists='append',index=False)
except:
    print('stock_lhb_jgstatistic_em_df数据库写入失败')
#接口能正常返回数据但日期不对
stock_comment_detail_scrd_desire_em_df = ak.stock_comment_detail_scrd_desire_em(symbol="600000")
print(stock_comment_detail_scrd_desire_em_df)
#接口报错不重要
stock_corporate_governance_guarantee_df = ak.stock_cg_guarantee_cninfo(symbol="全部", start_date="20180630", end_date="20210927")
print(stock_corporate_governance_guarantee_df)
